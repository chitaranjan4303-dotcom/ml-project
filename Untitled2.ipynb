# %% [markdown]
# <a href="https://colab.research.google.com/github/chitaranjan4303-dotcom/ml-project/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def process_scores(students):
  averaged_data = {}
  for name,scores in students.items():
    avg = sum(scores)/len(scores)
    averaged_data[name] = round(avg,2)
  return averaged_data
def classify_grades(averages):
  final_report = {}
  A_grade = [90]
  B_grade = [80]
  C_grade = [70]
  D_grade = [60]
  for name,avg in averages.items():
    if avg >= A_grade:
      grade = 'A'
    elif avg >= B_grade:
      grade = 'B'
    elif avg >= C_grade:
      grade = 'C'
    elif avg >= D_grade:
      grade = 'D'
    else:
        grade = 'F'
    final_report[name] = (avg,grade)
  return final_report
  student_data = {
    "Aryan": [85, 90, 92],
    "Aditya": [95,98,97],
    "Arun": [60,55,62]}
  report = classify_grades(averages)
  print(report)
